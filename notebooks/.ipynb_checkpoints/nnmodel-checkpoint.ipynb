# %% [markdown]
# ## 🧠 Neural Network Model
#
# This notebook builds a PyTorch-based neural network to predict customer churn:
# - Custom architecture defined using `nn.Module`
# - Trained using BCE loss and Adam optimizer
# - Evaluation includes accuracy, precision, recall, F1 score, and threshold tuning
#
# Key Takeaway: Neural Network slightly outperformed other models in terms of accuracy and F1 score.

# %%
import joblib

# Load preprocessed data
X_train = joblib.load('../data/X_train.pkl')
X_test = joblib.load('../data/X_test.pkl')
y_train = joblib.load('../data/y_train.pkl')
y_test = joblib.load('../data/y_test.pkl')

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).unsqueeze(1)

X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).unsqueeze(1)

# %%
class ChurnDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_dataset = ChurnDataset(X_train_tensor, y_train_tensor)
test_dataset = ChurnDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64)

# %%
import torch.nn as nn

class ChurnModel(nn.Module):
    def __init__(self, input_dim):
        super(ChurnModel, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
input_dim = X_train.shape[1]
model = ChurnModel(input_dim).to(device)

# %%
import torch.optim as optim

criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
from sklearn.metrics import accuracy_score

num_epochs = 25
train_losses = []
val_losses = []
val_accuracies = []

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
    
    train_losses.append(epoch_loss / len(train_loader))

    # Validation
    model.eval()
    val_preds = []
    val_targets = []
    val_loss = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item()

            preds = (outputs >= 0.5).float()
            val_preds.extend(preds.cpu().numpy())
            val_targets.extend(labels.cpu().numpy())

    val_accuracy = accuracy_score(val_targets, val_preds)
    val_losses.append(val_loss / len(test_loader))
    val_accuracies.append(val_accuracy)

    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {train_losses[-1]:.4f} "
          f"Val Loss: {val_losses[-1]:.4f} "
          f"Val Accuracy: {val_accuracy:.4f}")
# Out:
# Epoch [1/25] Train Loss: 0.5294 Val Loss: 0.4461 Val Accuracy: 0.7939
# Epoch [2/25] Train Loss: 0.4375 Val Loss: 0.4345 Val Accuracy: 0.7925
# Epoch [3/25] Train Loss: 0.4291 Val Loss: 0.4325 Val Accuracy: 0.7910
# Epoch [4/25] Train Loss: 0.4240 Val Loss: 0.4303 Val Accuracy: 0.7974
# Epoch [5/25] Train Loss: 0.4246 Val Loss: 0.4306 Val Accuracy: 0.7939
# Epoch [6/25] Train Loss: 0.4184 Val Loss: 0.4295 Val Accuracy: 0.7967
# Epoch [7/25] Train Loss: 0.4200 Val Loss: 0.4299 Val Accuracy: 0.7960
# Epoch [8/25] Train Loss: 0.4160 Val Loss: 0.4300 Val Accuracy: 0.7953
# Epoch [9/25] Train Loss: 0.4170 Val Loss: 0.4282 Val Accuracy: 0.7925
# Epoch [10/25] Train Loss: 0.4131 Val Loss: 0.4293 Val Accuracy: 0.7989
# Epoch [11/25] Train Loss: 0.4139 Val Loss: 0.4294 Val Accuracy: 0.7903
# Epoch [12/25] Train Loss: 0.4137 Val Loss: 0.4280 Val Accuracy: 0.7967
# Epoch [13/25] Train Loss: 0.4134 Val Loss: 0.4285 Val Accuracy: 0.7875
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Loss Curve
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.legend()

# Accuracy Curve
plt.subplot(1, 2, 2)
plt.plot(val_accuracies, label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy Over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predict on the entire test set
model.eval()
all_preds = []
all_targets = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        preds = (outputs >= 0.5).float()
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(labels.cpu().numpy())

# Confusion matrix
cm = confusion_matrix(all_targets, all_preds)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["No", "Yes"], yticklabels=["No", "Yes"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Classification report
print(classification_report(all_targets, all_preds, target_names=["No", "Yes"]))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.87      1033
#          Yes       0.64      0.53      0.58       374
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.71      0.72      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
from sklearn.metrics import f1_score, classification_report
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Get the probabilities (assuming y_pred_proba_nn is already available)
# Ensure the test tensor is on the same device as the model
X_test_tensor = X_test_tensor.to(device)

# Predict probabilities
y_pred_proba_nn = model(X_test_tensor).detach().cpu().numpy().flatten()

# Step 2: Search for best threshold based on F1-score
thresholds = np.arange(0.1, 0.9, 0.01)
f1_scores = []

for t in thresholds:
    preds = (y_pred_proba_nn >= t).astype(int)
    f1 = f1_score(y_test, preds)
    f1_scores.append(f1)

# Step 3: Find the best threshold
best_idx = np.argmax(f1_scores)
best_threshold_nn = thresholds[best_idx]
print(f"Best Threshold (Neural Network based on F1): {best_threshold_nn:.2f}")

# Step 4: Final predictions using the best threshold
y_pred_thresh_nn = (y_pred_proba_nn >= best_threshold_nn).astype(int)

# Step 5: Show classification report
print("Classification Report (After Threshold Tuning - Neural Network):")
print(classification_report(y_test, y_pred_thresh_nn))

# Step 6 (Optional): Plot threshold vs F1-score
plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, label='F1 Score')
plt.axvline(x=best_threshold_nn, color='r', linestyle='--', label=f'Best Threshold = {best_threshold_nn:.2f}')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.title('Threshold Tuning - Neural Network')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Best Threshold (Neural Network based on F1): 0.36
# Classification Report (After Threshold Tuning - Neural Network):
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84      1033
#            1       0.57      0.70      0.63       374
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.76      0.74      1407
# weighted avg       0.80      0.78      0.79      1407

# %%
from sklearn.metrics import f1_score
import numpy as np

best_threshold = 0
best_f1 = 0
thresholds = np.arange(0.1, 0.9, 0.01)

for t in thresholds:
    y_pred_thresh_nn = (y_pred_proba_nn >= t).astype(int)
    score = f1_score(y_test, y_pred_thresh_nn)
    if score > best_f1:
        best_f1 = score
        best_threshold = t

print(f"Best Threshold (Neural Network based on F1): {best_threshold:.2f}")
# Out:
# Best Threshold (Neural Network based on F1): 0.36

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the best threshold
y_pred_thresh_nn = (y_pred_proba_nn >= best_threshold).astype(int)

# Print classification report
print("Classification Report (After Threshold Tuning - Neural Network):")
print(classification_report(y_test, y_pred_thresh_nn))

# Confusion matrix
cm_nn = confusion_matrix(y_test, y_pred_thresh_nn)
plt.figure(figsize=(6,4))
sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Neural Network Confusion Matrix (After Threshold Tuning)')
plt.show()
# Out:
# Classification Report (After Threshold Tuning - Neural Network):
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84      1033
#            1       0.57      0.70      0.63       374
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.76      0.74      1407
# weighted avg       0.80      0.78      0.79      1407

# %%
import joblib

joblib.dump(y_pred_proba_nn, '../data/y_pred_proba_nn.csv')
joblib.dump(best_threshold, '../data/threshold_nn.csv')
joblib.dump(y_pred_thresh_nn, '../data/y_pred_thresh_nn.csv')
# Out:
# ['../data/y_pred_thresh_nn.csv']

# %%
# Save the model's state_dict
torch.save(model.state_dict(), '../models/nn_model.pth')
