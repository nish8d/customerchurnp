# %% [markdown]
# ## 📊 Exploratory Data Analysis (EDA)
#
# This notebook covers the initial data analysis steps for the customer churn dataset. It includes:
# - Data cleaning and preprocessing
# - Handling missing values and encoding categorical features
# - Visualization of feature distributions and correlations
# - Insights into churn vs. non-churn customers
#
# Key Takeaway: Identified important features potentially influencing churn, guiding further modeling efforts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset from the data folder
df = pd.read_csv('D:/datascienceprojects/customerchurnp/data/data.csv')

# Display the first 5 rows
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Get data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# - There are no missing values
# - Total charges shows to be an object type but it should be float type

# %%
# Try converting TotalCharges to numeric, coerce errors into NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Now check how many got converted to NaN
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
# Drop rows where TotalCharges is NaN
df = df[df['TotalCharges'].notnull()]

# Reset index (optional but cleaner)
df.reset_index(drop=True, inplace=True)

# Confirm no more NaNs
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Value counts (absolute)
df['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
# Value counts (percentage)
df['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %% [markdown]
# - The data is imbalanced as the percentages of no churn and churn are so far apart.

# %% [markdown]
# ---

# %%
# Exclude ID column
df = df.drop(columns=['customerID'])

# Separate columns by data type
categorical_cols = df.select_dtypes(include='object').columns.tolist()
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove target from categorical (if present)
categorical_cols.remove('Churn')

print("Categorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# Numerical columns: ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
categorical_cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
# Set plot style
sns.set(style="whitegrid")

# Set figure size
plt.figure(figsize=(20, 25))

# Loop through all categorical features
for i, col in enumerate(categorical_cols):
    plt.subplot(5, 3, i + 1)
    sns.countplot(data=df, x=col, hue='Churn')
    plt.title(f"{col} vs Churn", fontsize=15)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - Gender does not seem to be a significant feature
# - Partners and Dependents seem to be highly correlated to the churn rate
# - The rest of the features seem to show slight trends as well

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 10))

for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.histplot(data=df, x=col, hue='Churn', kde=True, multiple='stack', palette='Set2')
    plt.title(f"{col} Distribution by Churn", fontsize=12)
    plt.tight_layout()

plt.show()

# %%
# Encode churn as 1 (Yes) and 0 (No) to use in correlation
df_corr = df.copy()
df_corr['Churn'] = df_corr['Churn'].map({'No': 0, 'Yes': 1})

# Correlation with target
print(df_corr.corr(numeric_only=True)['Churn'].sort_values(ascending=False))
# Out:
# Churn             1.000000
# MonthlyCharges    0.192858
# SeniorCitizen     0.150541
# TotalCharges     -0.199484
# tenure           -0.354049
# Name: Churn, dtype: float64

# %% [markdown]
# - Tenure and TotalCharges seem to be negatively correlated to the churn rate

# %%
# Boxplots
plt.figure(figsize=(18, 10))

for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(data=df, hue='Churn', y=col, palette='Set3')
    plt.title(f"{col} Boxplot by Churn", fontsize=12)
    plt.tight_layout()

plt.show()

# %%
categorical_cols
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
from sklearn.preprocessing import LabelEncoder

# Copy dataframe to avoid overwriting
df_encoded = df.copy()

# Binary categorical columns (can use LabelEncoder)
binary_cols = ['gender', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']

le = LabelEncoder()
for col in binary_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col])

# One-hot encode other categorical columns
df_encoded = pd.get_dummies(df_encoded, columns=[
    'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
    'Contract', 'PaymentMethod'
])

df_encoded.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# 0                 1           29.85         29.85      0  ...
# 1                 0           56.95       1889.50      0  ...
# 2                 1           53.85        108.15      1  ...
# 3                 0           42.30       1840.75      0  ...
# 4                 1           70.70        151.65      1  ...
#
#    StreamingMovies_No  StreamingMovies_No internet service  \
# 0                True                                False
# 1                True                                False
# ...

# %%
print("Label Encoded Mappings:")
for col in df_encoded:
    mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print(f"{col}: {mapping}")

# 2. Visualize one-hot encoded columns (grouped)
print("\nOne-Hot Encoded Columns:")
one_hot_cols = [
    'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
    'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
    'Contract', 'PaymentMethod'
]

# Count the number of dummy variables created per feature
dummy_counts = {col: len([c for c in df_encoded.columns if c.startswith(col + "_")]) for col in one_hot_cols}

# Plot it
plt.figure(figsize=(10, 5))
sns.barplot(hue=list(dummy_counts.keys()), y=list(dummy_counts.values()), palette='viridis')
plt.xticks(rotation=45)
plt.title("Number of One-Hot Encoded Columns Per Feature")
plt.ylabel("Number of Dummy Columns")
plt.tight_layout()
plt.show()
# Out:
# Label Encoded Mappings:
# gender: {'No': np.int64(0), 'Yes': np.int64(1)}
# SeniorCitizen: {'No': np.int64(0), 'Yes': np.int64(1)}
# Partner: {'No': np.int64(0), 'Yes': np.int64(1)}
# Dependents: {'No': np.int64(0), 'Yes': np.int64(1)}
# tenure: {'No': np.int64(0), 'Yes': np.int64(1)}
# PhoneService: {'No': np.int64(0), 'Yes': np.int64(1)}
# PaperlessBilling: {'No': np.int64(0), 'Yes': np.int64(1)}
# MonthlyCharges: {'No': np.int64(0), 'Yes': np.int64(1)}
# TotalCharges: {'No': np.int64(0), 'Yes': np.int64(1)}
# Churn: {'No': np.int64(0), 'Yes': np.int64(1)}
# MultipleLines_No: {'No': np.int64(0), 'Yes': np.int64(1)}
# MultipleLines_No phone service: {'No': np.int64(0), 'Yes': np.int64(1)}
# MultipleLines_Yes: {'No': np.int64(0), 'Yes': np.int64(1)}
# InternetService_DSL: {'No': np.int64(0), 'Yes': np.int64(1)}
# InternetService_Fiber optic: {'No': np.int64(0), 'Yes': np.int64(1)}
# InternetService_No: {'No': np.int64(0), 'Yes': np.int64(1)}
# ...

# %%
df_encoded.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# 0                 1           29.85         29.85      0  ...
# 1                 0           56.95       1889.50      0  ...
# 2                 1           53.85        108.15      1  ...
# 3                 0           42.30       1840.75      0  ...
# 4                 1           70.70        151.65      1  ...
#
#    StreamingMovies_No  StreamingMovies_No internet service  \
# 0                True                                False
# 1                True                                False
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. Drop 'customerID' (not useful for prediction)
df_model = df_encoded.copy()

# 2. Separate label (target)
X = df_model.drop('Churn', axis=1)
y = df_model['Churn']

# 3. Train-test split (stratify = preserve churn balance)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# 4. Scale numerical columns only
numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

scaler = StandardScaler()

# Fit only on training data to prevent data leakage
X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = scaler.transform(X_test[numerical_cols])

# %%
df_model.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7032.000000    7032.000000  7032.000000  7032.000000  7032.000000
# mean      0.504693       0.162400     0.482509     0.298493    32.421786
# std       0.500014       0.368844     0.499729     0.457629    24.545260
# min       0.000000       0.000000     0.000000     0.000000     1.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  \
# count   7032.000000       7032.000000     7032.000000   7032.000000
# mean       0.903299          0.592719       64.798208   2283.300441
# std        0.295571          0.491363       30.085974   2266.771362
# ...

# %%
import joblib

# Save train-test split
joblib.dump(X_train, 'D:/datascienceprojects/customerchurnp/data/X_train.pkl')
joblib.dump(X_test, 'D:/datascienceprojects/customerchurnp/data/X_test.pkl')
joblib.dump(y_train, 'D:/datascienceprojects/customerchurnp/data/y_train.pkl')
joblib.dump(y_test, 'D:/datascienceprojects/customerchurnp/data/y_test.pkl')
# Out:
# ['D:/datascienceprojects/customerchurnp/data/y_test.pkl']

# %%
import joblib

# Save train-test split
joblib.dump(X_train, 'D:/datascienceprojects/customerchurnp/data/X_train.csv')
joblib.dump(X_test, 'D:/datascienceprojects/customerchurnp/data/X_test.csv')
joblib.dump(y_train, 'D:/datascienceprojects/customerchurnp/data/y_train.csv')
joblib.dump(y_test, 'D:/datascienceprojects/customerchurnp/data/y_test.csv')
# Out:
# ['D:/datascienceprojects/customerchurnp/data/y_test.csv']

# %% [markdown]
# ---
